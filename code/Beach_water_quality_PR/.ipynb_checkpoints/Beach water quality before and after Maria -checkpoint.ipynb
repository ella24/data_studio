# %% [markdown]
# Some Beaches included in water monitoring system in Puerto Rico
# • Balneario El Escambrón - San Juan
# • Balneario de Carolina
# • Balneario Monserrate - Luquillo·
# • Playa Flamenco - Culebra
# • Balneario Punta Santiago - Humacao
# • Balneario Seven Seas - Fajardo
# • Balneario Punta Aguilarte - Arroyo
# • Balneario de Patillas
# • Playa Buyé - Cabo Rojo
# • Balneario de Rincón - Rincón
# • Balneario Caña Gorda - Guánica
# • Balneario Boquerón - Cabo Rojo
# • Playa Combate - Cabo Rojo
# • Balneario Puerto Nuevo - Vega Baja
# • Playa Santa - Guánica
# • Balneario de Añasco - Añasco
# • Playa Moja Casabe - Cabo Rojo
# • Balneario Crash Boat - Aguadilla
# • Balneario Cerro Gordo -Vega Alta
# • Balneario Sardinera - Dorado
# • Balneario Punta Salinas - Toa Baja·
# • Balneario Pico de Piedra - Aguada
# • Balneario Sun Bay - Vieques

# %% [markdown]
# t's been almost a year since Hurricane Maria slammed into Puerto Rico. There are still people without a safe roof over their heads and electricity in their houses. However, islanders will always find the beach to be the place where they can let go of all worries and enjoy quality time. Beaches in Puerto Rico are a main attraction for foreigners and locals since they are warm all year round. Yet one cannot forget that the environment impacts of a category four hurricane does not disappear in a short period of time. On the island all the rivers went out of their channel and dragged debris and dead animals for months. This project intends to answer the questions of many locals and visitors have:
#
# Are Puerto Rican beaches in a good state after Maria or the data says something different?
# What’s the beach water quality of the most visited beaches?
# Has the hurricane have a life long impact on beach water quality?

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from cycler import cycler
# %matplotlib inline
import seaborn as sns

# %%
plt.rcdefaults()
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'font.family': 'sans-serif',
    'font.sans-serif' : 'Tahoma',
    'axes.facecolor' : '#ffffff',
    'axes.axisbelow':True, 
    'axes.grid' : True,
    'grid.color' : '#bec0c2',
    'grid.linestyle' : 'dotted',
    'axes.spines.left'   : False,   
    'axes.spines.bottom' : False,
    'axes.spines.top'    : False,
    'axes.spines.right' : False,
    'axes.prop_cycle': cycler('color', ['mediumseagreen','mediumaquamarine','mediumturquoise','cadetblue','skyblue','teal',
                                        'mediumspringgreen','seagreen']),
    'xtick.bottom'  : False,
    'ytick.left': False,
    'figure.titlesize' : 'large', 
    'figure.titleweight' : 'bold',
    'figure.facecolor' : '#ffffff',
    'text.color' : '#595959',
    'axes.labelcolor' : '#595959',
    'xtick.color' : '#595959',
    'ytick.color' : '#595959',
    'legend.loc' : 'best',
    'legend.fancybox'    : True,
    'legend.frameon'     : True,
    'legend.edgecolor'     : '0.9',
    'legend.markerscale'   : '0.5',
    'lines.marker'      : None,
    'lines.markersize'  : 3,           
})

# %%
playas=pd.read_csv('Monitoreo de Playas Puerto Rico')
playas=playas.drop(columns=['3'])

# %%
playas.dtypes
# Out:
# Date                                   object
# Beach ID                               object
# Beach Name                             object
# Latitude                              float64
# Longitude                             float64
# Sampling Route                         object
# Sampling Type                          object
# Enterococcus\r\n (colonies/100 mL)     object
# Temperature\r\n(°C)                    object
# pH                                     object
# Observations                           object
# dtype: object

# %%
playas.head()
# Out:
#                   Date Beach ID                                    Beach Name  \
# 0  2017-11-27 00:00:00    RW-18  Balneario Manuel “Nolo” Morales or Sardinera
# 1  2017-11-27 00:00:00    RW-19                       Balneario Punta Salinas
# 2  2017-11-27 00:00:00   RW-20A                        Balneario El Escambrón
# 3  2017-11-27 00:00:00   RW-25A                           Playa Sixto Escobar
# 4  2017-11-27 00:00:00    RW-26                           Playita del Condado
#
#     Latitude  Longitude           Sampling Route Sampling Type  \
# 0  18.474694 -66.280892  Route 1: Dorado - Loíza       Routine
# 1  18.471658 -66.185994  Route 1: Dorado - Loíza       Routine
# 2  18.467236 -66.089958  Route 1: Dorado - Loíza       Routine
# 3  18.466731 -66.086667  Route 1: Dorado - Loíza       Routine
# 4  18.461131 -66.082408  Route 1: Dorado - Loíza       Routine
#
#   Enterococcus\r\n (colonies/100 mL) Temperature\r\n(°C)        pH   \
# 0                                 10                26.8       8.02
# 1                                 41                27.5       7.95
# 2                                 10                28.5       7.99
# 3                                 10                28.2       8.02
# 4                                 10                28.5  8.11/8.12
#
#   Observations
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
playas.columns
# Out:
# Index(['Date', 'Beach ID', 'Beach Name', 'Latitude', 'Longitude',
#        'Sampling Route', 'Sampling Type', 'Enterococcus\r\n (colonies/100 mL)',
#        'Temperature\r\n(°C)', 'pH ', 'Observations'],
#       dtype='object')

# %%
playas['Date']=playas['Date'].str.extract(r'(\d\d\d\d-\d\d-\d\d)')

# %%
playas.to_csv('Monitoreo de Playas 2018', index=False)

# %%
playas2=pd.read_csv("Monitoreo 2016 y 2017.csv")
playas2.head()
# Out:
#          Date Beach ID                                      Beach Name  \
# 0  2016-10-03    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 1  2016-10-03     RW-5                             Balneario de Rincón
# 2  2016-10-03    RW-22                                  Pico de Piedra
# 3  2016-10-03    RW-16                            Balneario Crash Boat
# 4  2016-10-03    RW-37                                    Villa Lamela
#
#     Latitude  Longitude               Sampling Route Sampling Type  \
# 0  18.287997 -67.193922  Route 5: Añasco - Aguadilla       Routine
# 1  18.340925 -67.256006  Route 5: Añasco - Aguadilla       Routine
# 2  18.384364 -67.212989  Route 5: Añasco - Aguadilla       Routine
# 3  18.457667 -67.163778  Route 5: Añasco - Aguadilla       Routine
# 4  18.064533 -67.197528           Route 4: Cabo Rojo       Routine
#
#   Enterococcus\r\n (colonies/100 mL) Temperature\r\n(°C)        pH   \
# 0                                146               29.00       8.14
# 1                                275               29.10       8.16
# 2                                 10               28.80       8.18
# 3                                 10               28.90  8.12/8.12
# 4                                 20               28.50       8.16
#
#   Observations
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
playas3=pd.read_csv("Monitoreo 2015 y 2016.csv")
playas3=playas3.drop(columns=['Observations','Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15',
                      'Unnamed: 16','Unnamed: 17','Unnamed: 18'])

# %%
playas3.head(3)
# Out:
#          Date Beach ID             Beach Name   Latitude  Longitude  \
# 0  2015-10-05   RW-12B       Playa el Combate  17.974794 -67.212906
# 1  2015-10-05   RW-14A      Playa Moja Casabe  17.985810 -67.214590
# 2  2015-10-05    RW-13  Balneario de Boquerón  18.019442 -67.172244
#
#        Sampling Route Sampling Type Enterococcus\r\n (colonies/100 mL)  \
# 0  Route 4: Cabo Rojo       Routine                                 10
# 1  Route 4: Cabo Rojo       Routine                                  1
# 2  Route 4: Cabo Rojo       Routine                                 10
#
#   Temperature\r\n(°C)        pH
# 0               30.20  7.88/7.87
# 1               30.30       7.88
# 2               30.40       7.99

# %%
playasdePuertoRico=pd.concat([playas2,playas],sort=False, ignore_index=True)
playasdePuertoRico.head()
# Out:
#          Date Beach ID                                      Beach Name  \
# 0  2016-10-03    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 1  2016-10-03     RW-5                             Balneario de Rincón
# 2  2016-10-03    RW-22                                  Pico de Piedra
# 3  2016-10-03    RW-16                            Balneario Crash Boat
# 4  2016-10-03    RW-37                                    Villa Lamela
#
#     Latitude  Longitude               Sampling Route Sampling Type  \
# 0  18.287997 -67.193922  Route 5: Añasco - Aguadilla       Routine
# 1  18.340925 -67.256006  Route 5: Añasco - Aguadilla       Routine
# 2  18.384364 -67.212989  Route 5: Añasco - Aguadilla       Routine
# 3  18.457667 -67.163778  Route 5: Añasco - Aguadilla       Routine
# 4  18.064533 -67.197528           Route 4: Cabo Rojo       Routine
#
#   Enterococcus\r\n (colonies/100 mL) Temperature\r\n(°C)        pH   \
# 0                                146               29.00       8.14
# 1                                275               29.10       8.16
# 2                                 10               28.80       8.18
# 3                                 10               28.90  8.12/8.12
# 4                                 20               28.50       8.16
#
#   Observations
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
playasdePuertoRico=pd.concat([playas3,playasdePuertoRico],sort=False, ignore_index=True)
playasdePuertoRico.head()
# Out:
#          Date Beach ID             Beach Name   Latitude  Longitude  \
# 0  2015-10-05   RW-12B       Playa el Combate  17.974794 -67.212906
# 1  2015-10-05   RW-14A      Playa Moja Casabe  17.985810 -67.214590
# 2  2015-10-05    RW-13  Balneario de Boquerón  18.019442 -67.172244
# 3  2015-10-05     RW-8            Playa Buyé   18.048872 -67.198625
# 4  2015-10-05    RW-37           Villa Lamela  18.064533 -67.197528
#
#        Sampling Route Sampling Type Enterococcus\r\n (colonies/100 mL)  \
# 0  Route 4: Cabo Rojo       Routine                                 10
# 1  Route 4: Cabo Rojo       Routine                                  1
# 2  Route 4: Cabo Rojo       Routine                                 10
# 3  Route 4: Cabo Rojo       Routine                                 10
# 4  Route 4: Cabo Rojo       Routine                                  1
#
#   Temperature\r\n(°C)        pH  Observations
# 0               30.20  7.88/7.87          NaN
# 1               30.30       7.88          NaN
# 2               30.40       7.99          NaN
# 3               29.90       7.88          NaN
# 4               29.50       8.01          NaN

# %%
#with pd.option_context('display.max_rows', None, 'display.max_columns', 3):
    #print(playasdePuertoRico)

# %%
playasdePuertoRico.to_csv('Toda Playa', sep='\t', encoding='utf-8')

# %%
playasdePuertoRico['Beach Name'].value_counts()
# Out:
# Tropical Beach                                     89
# Muelle de Arecibo                                  75
# Playa Guayanés                                     74
# Balneario Punta Guilarte                           65
# Balneario de Patillas                              65
# Playa Moja Casabe                                  64
# Balneario Punta Santiago                           63
# Balneario de Rincón                                63
# Balneario Seven Seas                               62
# Playa Buyé                                         62
# Balneario de Añasco or Balneario Tres Hermanos     61
# Balneario de Puerto Nuevo                          61
# Pico de Piedra                                     61
# Vacía Talega                                       59
# Villa Lamela                                       59
# Playita Rosada                                     58
# Balneario de Boquerón                              58
# Balneario Cerro Gordo or Javier Calderón Nieves    58
# Balneario Manuel “Nolo” Morales or Sardinera       58
# Balneario Crash Boat                               58
# Balneario Punta Salinas                            57
# Playa el Combate                                   56
# Balneario La Monserrate                            56
# Playa Sixto Escobar                                55
# Balneario de Salinas                               55
# Playa Santa                                        54
# Playa El Alambique                                 54
# Ocean Park                                         54
# Playa Azul                                         53
# Caña Gorda                                         53
# Balneario El Escambrón                             53
# Playita del Condado                                52
# Balneario de Carolina                              52
# Mar Chiquita                                       50
# Playa Cabullón                                     40
# Balneario Sun Bay                                  26
# Playa del Hilton                                   15
# Playa Flamenco                                      5
# Playa Jauca                                         3
# Playa Pelícano                                      2
# Playa Guayanés                                      1
# Balneario Punta Guilare                             1
# Balneario Manuel "Nolo" Morales or Sardinera        1
#  Villa Lamela                                       1
# Playa Pelicano                                      1
# Name: Beach Name, dtype: int64

# %%
import re

# %%
playasdePuertoRico['Enterococcus\r\n (colonies/100 mL)']=playasdePuertoRico['Enterococcus\r\n (colonies/100 mL)'].fillna(0)

# %%
playasdePuertoRico['Enterococcus\r\n (colonies/100 mL)']=playasdePuertoRico['Enterococcus\r\n (colonies/100 mL)'].str.extract(r'<?(.*)')

# %%
playasdePuertoRico['Enterococcus\r\n (colonies/100 mL)'].describe()
# Out:
# count     2122
# unique     236
# top         10
# freq      1068
# Name: Enterococcus\r\n (colonies/100 mL), dtype: object

# %%
playasdePuertoRico['Enterococcus\r\n (colonies/100 mL)']=pd.to_numeric(playasdePuertoRico['Enterococcus\r\n (colonies/100 mL)'], errors='coerce')

# %%
# Under the Puerto Rican Enviromental Authorities, Enterococci concentrations  for  a  single  sample  
#shall  not  exceed  70 Colony  Forming  Units  (CFUs)  per 100  mL 
#El parámetro de enterococos excede el "Beach Action Value" aplicable cuando:
#El resultado del análisis bacteriológico es mayor de 70 colonias por cada 100 mililitros de agua (colonias /100mL).

playas_sucias = playasdePuertoRico[playasdePuertoRico['Enterococcus\r\n (colonies/100 mL)'] > 70]
playas_sucias.shape
# Out:
# (413, 11)

# %%
playas_sucias['Date']=pd.to_datetime(playas_sucias['Date'],format='%Y-%m-%d')
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
playas_sucias.columns
# Out:
# Index(['Date', 'Beach ID', 'Beach Name', 'Latitude', 'Longitude',
#        'Sampling Route', 'Sampling Type', 'Enterococcus\r\n (colonies/100 mL)',
#        'Temperature\r\n(°C)', 'pH ', 'Observations'],
#       dtype='object')

# %%
playas_sucias['Year'] = playas_sucias['Date'].dt.year
playas_sucias['Month'] = playas_sucias['Date'].dt.month

# %%
playas_sucias=playas_sucias.rename(columns={'Enterococcus\r\n (colonies/100 mL)':'Enterococcus_colonies'})
playas_sucias
# Out:
#            Date Beach ID                                       Beach Name  \
# 30   2015-10-06     RW-7                         Balneario Punta Guilarte
# 32   2015-10-06    RW-30                                   Playa Guayanés
# 34   2015-10-06    RW-31                                   Tropical Beach
# 38   2015-10-13     RW-7                         Balneario Punta Guilarte
# 39   2015-10-13    RW-30                                   Playa Guayanés
# 44   2015-10-19    RW-34                                 Playa del Hilton
# 46   2015-10-19    RW-36                             Balneario de Salinas
# 58   2015-10-20    RW-23                        Balneario de Puerto Nuevo
# 59   2015-10-20    RW-17  Balneario Cerro Gordo or Javier Calderón Nieves
# 64   2015-10-20    RW-26                              Playita del Condado
# 71   2015-10-20    RW-30                                   Playa Guayanés
# 73   2015-10-20    RW-31                                   Tropical Beach
# 79   2015-10-06    RW-30                                   Playa Guayanés
# 80   2015-10-06    RW-31                                   Tropical Beach
# 81   2015-10-06    RW-23                        Balneario de Puerto Nuevo
# 85   2015-11-02   RW-14A                                Playa Moja Casabe
# 96   2015-11-02     RW-5                              Balneario de Rincón
# 99   2015-11-03    RW-18     Balneario Manuel “Nolo” Morales or Sardinera
# 102  2015-11-03   RW-25A                              Playa Sixto Escobar
# 108  2015-11-03     RW-7                         Balneario Punta Guilarte
# 109  2015-11-03     RW-6                            Balneario de Patillas
# 110  2015-11-03    RW-30                                   Playa Guayanés
# 112  2015-11-03    RW-31                                   Tropical Beach
# 116  2015-11-03    RW-38                                Muelle de Arecibo
# 119  2015-11-03    RW-17  Balneario Cerro Gordo or Javier Calderón Nieves
# 121  2015-11-09    RW-17  Balneario Cerro Gordo or Javier Calderón Nieves
# 124  2015-11-09     RW-7                         Balneario Punta Guilarte
# 125  2015-11-09     RW-6                            Balneario de Patillas
# 126  2015-11-09    RW-30                                   Playa Guayanés
# 127  2015-11-09    RW-31                                   Tropical Beach
# ...         ...      ...                                              ...
# 1831 2018-04-17    RW-31                                   Tropical Beach
# 1849 2018-04-17    RW-38                                Muelle de Arecibo
# 1853 2018-04-23    RW-30                                   Playa Guayanés
# 1854 2018-04-23    RW-31                                   Tropical Beach
# 1855 2018-04-23    RW-38                                Muelle de Arecibo
# 1871 2018-05-02    RW-31                                   Tropical Beach
# 1882 2018-04-30    RW-13                            Balneario de Boquerón
# 1893 2018-05-07    RW-31                                   Tropical Beach
# 1895 2018-05-07    RW-31                                   Tropical Beach
# 1907 2018-05-15     RW-6                            Balneario de Patillas
# 1908 2018-05-15    RW-30                                   Playa Guayanés
# 1909 2018-05-15     RW-4                         Balneario Punta Santiago
# 1923 2018-05-14   RW-12B                                 Playa el Combate
# 1933 2018-05-21    RW-30                                   Playa Guayanés
# 1947 2018-05-30    RW-30                                   Playa Guayanés
# 1949 2018-05-30    RW-31                                   Tropical Beach
# 1967 2018-05-30    RW-38                                Muelle de Arecibo
# 1972 2018-06-04    RW-30                                   Playa Guayanés
# 1987 2018-06-12    RW-31                                   Tropical Beach
# 1988 2018-06-12     RW-2                             Balneario Seven Seas
# 2002 2018-06-11     RW-5                              Balneario de Rincón
# 2005 2018-06-11    RW-38                                Muelle de Arecibo
# 2031 2018-06-25    RW-10                                      Playa Santa
# 2032 2018-06-25     RW-9                                       Caña Gorda
# 2033 2018-06-25    RW-34                                   Playa Cabullón
# 2034 2018-06-25    RW-36                             Balneario de Salinas
# 2049 2018-07-02     RW-9                                       Caña Gorda
# 2075 2018-07-16     RW-8                                      Playa Buyé
# 2099 2018-07-31    RW-30                                   Playa Guayanés
# 2114 2018-07-30   RW-12B                                 Playa el Combate
#
#        Latitude  Longitude                  Sampling Route Sampling Type  \
# 30    17.962042 -66.040000      Route 2: Arroyo - Luquillo       Routine
# 32    18.062694 -65.819194      Route 2: Arroyo - Luquillo       Routine
# 34    18.186928 -65.725967      Route 2: Arroyo - Luquillo       Routine
# 38    17.962042 -66.040000      Route 2: Arroyo - Luquillo   Re-sampling
# 39    18.062694 -65.819194      Route 2: Arroyo - Luquillo   Re-sampling
# 44    17.969283 -66.602728        Route 3: Lajas - Salinas       Routine
# 46    17.977589 -66.332497        Route 3: Lajas - Salinas       Routine
# 58    18.491367 -66.399044  Route: 6: Arecibo – Vega Alta        Routine
# 59    18.481250 -66.340656  Route: 6: Arecibo – Vega Alta        Routine
# 64    18.461131 -66.082408         Route 1: Dorado - Loíza       Routine
# 71    18.062694 -65.819194      Route 2: Arroyo - Luquillo       Routine
# 73    18.186928 -65.725967      Route 2: Arroyo - Luquillo       Routine
# 79    18.062694 -65.819194      Route 2: Arroyo - Luquillo   Re-sampling
# 80    18.186928 -65.725967      Route 2: Arroyo - Luquillo   Re-sampling
# 81    18.491367 -66.399044  Route: 6: Arecibo – Vega Alta    Re-sampling
# 85    17.985810 -67.214590              Route 4: Cabo Rojo       Routine
# 96    18.340925 -67.256006     Route 5: Añasco - Aguadilla       Routine
# 99    18.474694 -66.280892         Route 1: Dorado - Loíza       Routine
# 102   18.466731 -66.086667         Route 1: Dorado - Loíza       Routine
# 108   17.962042 -66.040000      Route 2: Arroyo - Luquillo       Routine
# 109   17.973975 -65.988981      Route 2: Arroyo - Luquillo       Routine
# 110   18.062694 -65.819194      Route 2: Arroyo - Luquillo       Routine
# 112   18.186928 -65.725967      Route 2: Arroyo - Luquillo       Routine
# 116   18.479258 -66.700467  Route: 6: Arecibo – Vega Alta        Routine
# 119   18.481250 -66.340656  Route: 6: Arecibo – Vega Alta        Routine
# 121   18.481250 -66.340656  Route: 6: Arecibo – Vega Alta    RE-sampling
# 124   17.962042 -66.040000      Route 2: Arroyo - Luquillo   RE-sampling
# 125   17.973975 -65.988981      Route 2: Arroyo - Luquillo   RE-sampling
# 126   18.062694 -65.819194      Route 2: Arroyo - Luquillo   RE-sampling
# 127   18.186928 -65.725967      Route 2: Arroyo - Luquillo   RE-sampling
# ...         ...        ...                             ...           ...
# 1831  18.186928 -65.725967      Route 2: Arroyo - Luquillo       Routine
# 1849  18.479258 -66.700467  Route: 6: Arecibo – Vega Alta        Routine
# 1853  18.062694 -65.819194      Route 2: Arroyo - Luquillo   Re-sampling
# 1854  18.186928 -65.725967      Route 2: Arroyo - Luquillo   Re-sampling
# 1855  18.479258 -66.700467  Route: 6: Arecibo – Vega Alta    Re-sampling
# 1871  18.186928 -65.725967      Route 2: Arroyo - Luquillo       Routine
# 1882  18.019442 -67.172244              Route 4: Cabo Rojo       Routine
# 1893  18.186928 -65.725967      Route 2: Arroyo - Luquillo   Re-sampling
# 1895  18.186928 -65.725967      Route 2: Arroyo - Luquillo   Re-sampling
# 1907  17.973975 -65.988981      Route 2: Arroyo - Luquillo       Routine
# 1908  18.062694 -65.819194      Route 2: Arroyo - Luquillo       Routine
# 1909  18.158414 -65.755186      Route 2: Arroyo - Luquillo       Routine
# 1923  17.974794 -67.212906              Route 4: Cabo Rojo       Routine
# 1933  18.062694 -65.819194      Route 2: Arroyo - Luquillo   Re-sampling
# 1947  18.062694 -65.819194      Route 2: Arroyo - Luquillo       Routine
# 1949  18.186928 -65.725967      Route 2: Arroyo - Luquillo       Routine
# 1967  18.479258 -66.700467  Route: 6: Arecibo – Vega Alta        Routine
# 1972  18.062694 -65.819194      Route 2: Arroyo - Luquillo   Re-sampling
# 1987  18.186928 -65.725967      Route 2: Arroyo - Luquillo       Routine
# 1988  18.369267 -65.636072      Route 2: Arroyo - Luquillo       Routine
# 2002  18.340925 -67.256006     Route 5: Añasco - Aguadilla       Routine
# 2005  18.479258 -66.700467  Route: 6: Arecibo – Vega Alta        Routine
# 2031        NaN        NaN                             NaN           NaN
# 2032        NaN        NaN                             NaN           NaN
# 2033        NaN        NaN                             NaN           NaN
# 2034        NaN        NaN                             NaN           NaN
# 2049        NaN        NaN                             NaN           NaN
# 2075  18.048872 -67.198625              Route 4: Cabo Rojo       Routine
# 2099  18.062694 -65.819194      Route 2: Arroyo - Luquillo       Routine
# 2114  17.974794 -67.212906              Route 4: Cabo Rojo       Routine
#
#       Enterococcus_colonies Temperature\r\n(°C)                          pH   \
# 30                     83.0               29.90                         7.97
# 32                    840.0               30.20                         8.02
# 34                     84.0               30.20                    7.97/7.98
# 38                     72.0               30.30  Bacteriological Re-sampling
# 39                    144.0               29.20  Bacteriological Re-sampling
# 44                     96.0               30.70                         8.15
# 46                    109.0               31.10                         8.12
# 58                     86.0               29.00                         8.04
# 59                    512.0               31.00                     7.99/8.0
# 64                    293.0               30.50                         8.16
# 71                    355.0               29.40                         7.96
# 73                    243.0               29.00                    7.93/7.93
# 79                    529.0               28.10  Bacteriological Re-sampling
# 80                     73.0               28.60  Bacteriological Re-sampling
# 81                     85.0               28.00  Bacteriological Re-sampling
# 85                    880.0               28.50                            8
# 96                     96.0               29.10                         8.12
# 99                    473.0               27.50                         7.86
# 102                  5172.0               27.80                         8.03
# 108                   132.0               27.70                            8
# 109                   122.0               27.50                        7.936
# 110                 24196.0               27.60                         7.96
# 112                   933.0               28.80                    8.07/8.08
# 116                   839.0               28.50                         8.11
# 119                   631.0               28.10                    8.13/8.13
# 121                    86.0               28.00  Bacteriological Re-sampling
# 124                   278.0               26.50  Bacteriological Re-sampling
# 125                   187.0               26.50  Bacteriological Re-sampling
# 126                   246.0               27.20  Bacteriological Re-sampling
# 127                  2187.0                0.46  Bacteriological Re-sampling
# ...                     ...                 ...                          ...
# 1831                  179.0                27.6                         8.15
# 1849                  109.0                26.4                          8.2
# 1853                  146.0                  26                  RE-sampling
# 1854                  272.0                  26                  RE-sampling
# 1855                  504.0                26.2                  RE-sampling
# 1871                  107.0                27.5                         8.28
# 1882                  120.0                28.4                         8.14
# 1893                  206.0                27.5                  Re-sampling
# 1895                  206.0                27.5                  Re-sampling
# 1907                  122.0                27.7                         8.14
# 1908                  122.0                27.5                         8.05
# 1909                   81.0                27.6                         8.14
# 1923                   86.0                28.3                    8.24/8.24
# 1933                   75.0                27.5                  RE-sampling
# 1947                   81.0                29.2                         8.09
# 1949                17329.0                27.9                         8.27
# 1967                  109.0                27.5                         8.26
# 1972                  174.0                  28                  Re-sampling
# 1987                  683.0                28.3                          8.1
# 1988                  828.0                28.7                         8.16
# 2002                   74.0                27.9                         8.08
# 2005                  110.0                26.6                         8.08
# 2031                   85.0                28.4                         6.89
# 2032                   86.0                  29                         6.79
# 2033                   82.0                28.7                         6.71
# 2034                  120.0                29.6                    6.75/6.80
# 2049                   84.0                  28                  Re-sampling
# 2075                   86.0                29.7                          8.1
# 2099                   96.0                28.1                            8
# 2114                   84.0                29.1                         8.27
#
#                                            Observations  Year  Month
# 30                                                  NaN  2015     10
# 32                                                  NaN  2015     10
# 34                                                  NaN  2015     10
# 38                                                  NaN  2015     10
# 39                                                  NaN  2015     10
# 44                                                  NaN  2015     10
# 46                                                  NaN  2015     10
# 58                                                  NaN  2015     10
# 59                                                  NaN  2015     10
# 64                                                  NaN  2015     10
# 71                                                  NaN  2015     10
# 73                                                  NaN  2015     10
# 79                                                  NaN  2015     10
# 80                                                  NaN  2015     10
# 81                                                  NaN  2015     10
# 85                                                  NaN  2015     11
# 96                                                  NaN  2015     11
# 99                                                  NaN  2015     11
# 102                                                 NaN  2015     11
# 108                                                 NaN  2015     11
# 109                                                 NaN  2015     11
# 110                                                 NaN  2015     11
# 112                                                 NaN  2015     11
# 116                                                 NaN  2015     11
# 119                                                 NaN  2015     11
# 121                                                 NaN  2015     11
# 124                                                 NaN  2015     11
# 125                                                 NaN  2015     11
# 126                                                 NaN  2015     11
# 127                                                 NaN  2015     11
# ...                                                 ...   ...    ...
# 1831                                                NaN  2018      4
# 1849                                                NaN  2018      4
# 1853  los resultados de enterococos fueron actualiza...  2018      4
# 1854  los resultados de enterococos fueron actualiza...  2018      4
# 1855  los resultados de enterococos fueron actualiza...  2018      4
# 1871                                                NaN  2018      5
# 1882                                                NaN  2018      4
# 1893                                                NaN  2018      5
# 1895                                                NaN  2018      5
# 1907                                                NaN  2018      5
# 1908                                                NaN  2018      5
# 1909                                                NaN  2018      5
# 1923                                                NaN  2018      5
# 1933                                                NaN  2018      5
# 1947                                                NaN  2018      5
# 1949                                                NaN  2018      5
# 1967                                                NaN  2018      5
# 1972                                                NaN  2018      6
# 1987                                                NaN  2018      6
# 1988                                                NaN  2018      6
# 2002                                                NaN  2018      6
# 2005                                                NaN  2018      6
# 2031                                                NaN  2018      6
# 2032                                                NaN  2018      6
# 2033                                                NaN  2018      6
# 2034                                                NaN  2018      6
# 2049                                                NaN  2018      7
# 2075                                                NaN  2018      7
# 2099                                                NaN  2018      7
# 2114                                                NaN  2018      7
#
# [413 rows x 13 columns]

# %%
data= playas_sucias.sort_values(by='Month').groupby('Year').Enterococcus_colonies.max()
data
# Out:
# Year
# 2015    24196.0
# 2016    24196.0
# 2017     4352.0
# 2018    17329.0
# Name: Enterococcus_colonies, dtype: float64

# %%
colors= ['mediumaquamarine','mediumturquoise','cadetblue','skyblue','teal',
                                        'mediumspringgreen','seagreen']
ax = data.plot(kind='pie',colors=colors, autopct='%1.0f%%')
#ax.set_title('Where does Female Data Journalists work?',pad=30,fontsize=20)
#ax.set_ylabel('')
#plt.gcf().text(0.1,0.9,'Source: LinkedIn, July 2018', ha='right',fontsize=8)
#plt.savefig('Companies_with_Most_Female_Data_Journalists.pdf')
plt.show()

# %%
#Water conditions after the hurricane. I must point out that the JCA did not take samples until Nov 27. 
#The hurricane hit on Sept 20th. 
Maria_year= playas_sucias[(playas_sucias['Year']==2017) & (playas_sucias['Month']>=11)]

# %%
df1= Maria_year.sort_values(by='Month',ascending=False).head(20)
ax= df1.plot(kind='barh', x='Beach Name', y='Enterococcus_colonies', figsize=(10,5),legend=False,rot=0,color='mediumaquamarine')
ax.set_title("Beach Water Quality in Puerto Rico after Maria in 2017", pad=30, fontsize=24)
ax.set_xlabel('Enterococci Count (MPN/100mL)')
plt.gcf().text(0.5, 0.91, "Bacteria samples exceeding Puerto Rico's Environmental Quality Board parameters", ha='center', fontsize=12)
plt.gca().invert_yaxis()
plt.savefig('each Water Quality in Puerto Rico after Maria in 2017')
plt.show()

# %%
playas_sucias.dtypes
# Out:
# Date                     datetime64[ns]
# Beach ID                         object
# Beach Name                       object
# Latitude                        float64
# Longitude                       float64
# Sampling Route                   object
# Sampling Type                    object
# Enterococcus_colonies           float64
# Temperature\r\n(°C)              object
# pH                               object
# Observations                     object
# Year                              int64
# Month                             int64
# dtype: object

# %%
df= playas_sucias.sort_values(by='Enterococcus_colonies',ascending=False).head(15)
ax= df.plot(kind='barh', x='Beach Name', y='Enterococcus_colonies', figsize=(10,5),legend=False,rot=0,color='mediumaquamarine')
ax.set_title("Overall Beach Water Quality in Puerto Rico from 2015", pad=30, fontsize=24)
ax.set_xlabel('Enterococci Count (MPN/100mL)')
plt.gcf().text(0.5, 0.91, "Beaches with bacteria samples exceeding Puerto Rico's Environmental Quality Board parameters from October 2015 to Present", ha='center', fontsize=12)
plt.gca().invert_yaxis()
plt.savefig("Overall Beach Water Quality in Puerto Rico from 2015")
plt.show()

# %%
#The most terrible sample
East= playas_sucias[playas_sucias['Sampling Route'].isin(['Route 2: Arroyo - Luquillo'])] 
East.Year.value_counts()
# Out:
# 2017    62
# 2016    53
# 2018    29
# 2015    22
# Name: Year, dtype: int64

# %%
df= East.sort_values(by='Enterococcus_colonies',ascending=False).head(15)
ax= df.plot(kind='barh', x='Beach Name', y='Year', figsize=(10,5),legend=False,rot=0,color='mediumaquamarine')
ax.set_title("Alarming bacteria results in South East Coast Beaches", pad=30, fontsize=24)
ax.set_xlabel('Enterococci Count (MPN/100mL)')
plt.gcf().text(0.5, 0.91, "The samples exceed Puerto Rico's Environmental Quality Board parameters", ha='center', fontsize=12)
plt.gca().invert_yaxis()
plt.savefig('Alarming bacteria results in South East Coast Beaches')
plt.show()

# %%
Oeste= playas_sucias[playas_sucias['Sampling Route'].isin(['Route 4: Cabo Rojo','Route 3: Lajas - Salinas',
                                                          'Route 5: Añasco - Aguadilla'])] 
Oeste
# Out:
#            Date Beach ID                                      Beach Name  \
# 44   2015-10-19    RW-34                                Playa del Hilton
# 46   2015-10-19    RW-36                            Balneario de Salinas
# 85   2015-11-02   RW-14A                               Playa Moja Casabe
# 96   2015-11-02     RW-5                             Balneario de Rincón
# 132  2015-11-16    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 137  2015-11-30    RW-10                                     Playa Santa
# 138  2015-11-30     RW-9                                      Caña Gorda
# 139  2015-11-30    RW-34                                Playa del Hilton
# 140  2015-11-30    RW-36                            Balneario de Salinas
# 141  2015-11-30    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 143  2015-11-30    RW-22                                  Pico de Piedra
# 177  2016-01-11    RW-34                                Playa del Hilton
# 182  2016-01-11   RW-14A                               Playa Moja Casabe
# 208  2016-01-25     RW-8                                     Playa Buyé
# 227  2016-02-08   RW-14A                               Playa Moja Casabe
# 230  2016-02-08     RW-5                             Balneario de Rincón
# 232  2016-02-08    RW-16                            Balneario Crash Boat
# 269  2016-02-22    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 270  2016-02-22     RW-5                             Balneario de Rincón
# 271  2016-02-22    RW-22                                  Pico de Piedra
# 276  2016-02-22   RW-14A                               Playa Moja Casabe
# 285  2016-03-07    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 286  2016-03-07     RW-5                             Balneario de Rincón
# 290  2016-03-07     RW-8                                     Playa Buyé
# 291  2016-03-07    RW-13                           Balneario de Boquerón
# 292  2016-03-07   RW-14A                               Playa Moja Casabe
# 293  2016-03-07   RW-12B                                Playa el Combate
# 348  2016-03-08   RW-14A                               Playa Moja Casabe
# 397  2016-06-06    RW-37                                    Villa Lamela
# 418  2016-06-20    RW-37                                    Villa Lamela
# ...         ...      ...                                             ...
# 1124 2017-05-02     RW-5                             Balneario de Rincón
# 1155 2017-05-08    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 1232 2017-05-30    RW-16                            Balneario Crash Boat
# 1240 2017-06-05    RW-16                            Balneario Crash Boat
# 1269 2017-06-12    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 1279 2017-06-21    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 1312 2017-06-26     RW-5                             Balneario de Rincón
# 1320 2017-07-05     RW-5                             Balneario de Rincón
# 1343 2017-07-10    RW-37                                    Villa Lamela
# 1344 2017-07-10     RW-8                                     Playa Buyé
# 1390 2017-07-24    RW-16                            Balneario Crash Boat
# 1399 2017-08-14    RW-37                                    Villa Lamela
# 1421 2017-08-15    RW-36                            Balneario de Salinas
# 1458 2017-08-28    RW-10                                     Playa Santa
# 1459 2017-08-28     RW-9                                      Caña Gorda
# 1460 2017-08-28    RW-34                                  Playa Cabullón
# 1461 2017-08-28    RW-36                            Balneario de Salinas
# 1463 2017-08-28     RW-8                                     Playa Buyé
# 1465 2017-08-28   RW-14A                               Playa Moja Casabe
# 1466 2017-08-28   RW-12B                                Playa el Combate
# 1467 2017-08-28    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 1470 2017-08-28    RW-16                            Balneario Crash Boat
# 1615 2018-01-08    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 1618 2018-01-08    RW-16                            Balneario Crash Boat
# 1625 2018-01-17    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 1882 2018-04-30    RW-13                           Balneario de Boquerón
# 1923 2018-05-14   RW-12B                                Playa el Combate
# 2002 2018-06-11     RW-5                             Balneario de Rincón
# 2075 2018-07-16     RW-8                                     Playa Buyé
# 2114 2018-07-30   RW-12B                                Playa el Combate
#
#        Latitude  Longitude               Sampling Route Sampling Type  \
# 44    17.969283 -66.602728     Route 3: Lajas - Salinas       Routine
# 46    17.977589 -66.332497     Route 3: Lajas - Salinas       Routine
# 85    17.985810 -67.214590           Route 4: Cabo Rojo       Routine
# 96    18.340925 -67.256006  Route 5: Añasco - Aguadilla       Routine
# 132   18.287997 -67.193922  Route 5: Añasco - Aguadilla       Routine
# 137   17.937711 -66.955197     Route 3: Lajas - Salinas       Routine
# 138   17.952531 -66.884561     Route 3: Lajas - Salinas       Routine
# 139   17.969283 -66.602728     Route 3: Lajas - Salinas       Routine
# 140   17.977589 -66.332497     Route 3: Lajas - Salinas       Routine
# 141   18.287997 -67.193922  Route 5: Añasco - Aguadilla       Routine
# 143   18.384364 -67.212989  Route 5: Añasco - Aguadilla       Routine
# 177   17.969283 -66.602728     Route 3: Lajas - Salinas       Routine
# 182   17.985810 -67.214590           Route 4: Cabo Rojo       Routine
# 208   18.048872 -67.198625           Route 4: Cabo Rojo       Routine
# 227   17.985810 -67.214590           Route 4: Cabo Rojo       Routine
# 230   18.340925 -67.256006  Route 5: Añasco - Aguadilla       Routine
# 232   18.457667 -67.163778  Route 5: Añasco - Aguadilla       Routine
# 269   18.287997 -67.193922  Route 5: Añasco - Aguadilla       Routine
# 270   18.340925 -67.256006  Route 5: Añasco - Aguadilla       Routine
# 271   18.384364 -67.212989  Route 5: Añasco - Aguadilla       Routine
# 276   17.985810 -67.214590           Route 4: Cabo Rojo       Routine
# 285   18.287997 -67.193922  Route 5: Añasco - Aguadilla       Routine
# 286   18.340925 -67.256006  Route 5: Añasco - Aguadilla       Routine
# 290   18.048872 -67.198625           Route 4: Cabo Rojo       Routine
# 291   18.019442 -67.172244           Route 4: Cabo Rojo       Routine
# 292   17.985810 -67.214590           Route 4: Cabo Rojo       Routine
# 293   17.974794 -67.212906           Route 4: Cabo Rojo       Routine
# 348   17.985810 -67.214590           Route 4: Cabo Rojo       Routine
# 397   18.064533 -67.197528           Route 4: Cabo Rojo       Routine
# 418   18.064533 -67.197528           Route 4: Cabo Rojo       Routine
# ...         ...        ...                          ...           ...
# 1124  18.340925 -67.256006  Route 5: Añasco - Aguadilla       Routine
# 1155  18.287997 -67.193922  Route 5: Añasco - Aguadilla   RE-sampling
# 1232  18.457667 -67.163778  Route 5: Añasco - Aguadilla       Routine
# 1240  18.457667 -67.163778  Route 5: Añasco - Aguadilla   RE-sampling
# 1269  18.287997 -67.193922  Route 5: Añasco - Aguadilla       Routine
# 1279  18.287997 -67.193922  Route 5: Añasco - Aguadilla   RE-sampling
# 1312  18.340925 -67.256006  Route 5: Añasco - Aguadilla       Routine
# 1320  18.340925 -67.256006  Route 5: Añasco - Aguadilla   RE-sampling
# 1343  18.064533 -67.197528           Route 4: Cabo Rojo      Routine
# 1344  18.048872 -67.198625           Route 4: Cabo Rojo      Routine
# 1390  18.457667 -67.163778  Route 5: Añasco - Aguadilla       Routine
# 1399  18.064533 -67.197528           Route 4: Cabo Rojo       Routine
# 1421  17.977589 -66.332497     Route 3: Lajas - Salinas       Routine
# 1458  17.937711 -66.955197     Route 3: Lajas - Salinas       Routine
# 1459  17.952531 -66.884561     Route 3: Lajas - Salinas       Routine
# 1460  17.969283 -66.602728     Route 3: Lajas - Salinas       Routine
# 1461  17.977589 -66.332497     Route 3: Lajas - Salinas       Routine
# 1463  18.048872 -67.198625           Route 4: Cabo Rojo       Routine
# 1465  17.985810 -67.214590           Route 4: Cabo Rojo       Routine
# 1466  17.974794 -67.212906           Route 4: Cabo Rojo       Routine
# 1467  18.287997 -67.193922  Route 5: Añasco - Aguadilla       Routine
# 1470  18.457667 -67.163778  Route 5: Añasco - Aguadilla       Routine
# 1615  18.287997 -67.193922  Route 5: Añasco - Aguadilla       Routine
# 1618  18.457667 -67.163778  Route 5: Añasco - Aguadilla       Routine
# 1625  18.287997 -67.193922  Route 5: Añasco - Aguadilla   RE-sampling
# 1882  18.019442 -67.172244           Route 4: Cabo Rojo       Routine
# 1923  17.974794 -67.212906           Route 4: Cabo Rojo       Routine
# 2002  18.340925 -67.256006  Route 5: Añasco - Aguadilla       Routine
# 2075  18.048872 -67.198625           Route 4: Cabo Rojo       Routine
# 2114  17.974794 -67.212906           Route 4: Cabo Rojo       Routine
#
#       Enterococcus_colonies Temperature\r\n(°C)                          pH   \
# 44                     96.0               30.70                         8.15
# 46                    109.0               31.10                         8.12
# 85                    880.0               28.50                            8
# 96                     96.0               29.10                         8.12
# 132                    86.0               28.30                          7.9
# 137                  1785.0               27.00                         8.05
# 138                   241.0               27.50                         8.07
# 139                   471.0               28.00                          8.1
# 140                   200.0               28.40                         8.06
# 141                    74.0               26.40                         8.31
# 143                    95.0               27.40                         8.22
# 177                    81.0               27.40                         8.09
# 182                   120.0               26.40                         7.89
# 208                    85.0               26.60                         7.89
# 227                    98.0               26.30                         8.16
# 230                   121.0               26.80                         7.94
# 232                   146.0               27.30                    7.98/7.98
# 269                   487.0               26.60                         8.13
# 270                   455.0               26.50                         8.07
# 271                    75.0               26.30                         8.13
# 276                   350.0               26.20                         7.88
# 285                   108.0               27.40                         8.06
# 286                   345.0               27.30                          8.1
# 290                  1314.0               26.20                            8
# 291                   122.0               27.20                         8.04
# 292                  1333.0               27.30                         8.08
# 293                   331.0               27.20                    8.06/8.06
# 348                   160.0               26.60                         8.12
# 397                    85.0               27.70                         7.99
# 418                   235.0               27.20                         7.81
# ...                     ...                 ...                          ...
# 1124                   97.0                28.1                         8.16
# 1155                  109.0                27.0  Bacteriological Re-sampling
# 1232                  218.0                29.1                    8.14/8.15
# 1240                  169.0                28.3  Bacteriological Re-sampling
# 1269                  105.0               28.30                            8
# 1279                  670.0                29.1  Bacteriological Re-sampling
# 1312                  209.0                29.1                         8.05
# 1320                  122.0                28.8  Bacteriological Re-sampling
# 1343                   74.0                30.9                         8.09
# 1344                   85.0                30.2                            8
# 1390                  231.0                30.1                         8.05
# 1399                  389.0                29.8                         7.95
# 1421                  120.0                30.3                    8.39/8.39
# 1458                  122.0                  29                         8.17
# 1459                  197.0                  30                          8.1
# 1460                  121.0                30.4                         8.27
# 1461                  223.0                30.7                    8.18/8.18
# 1463                  132.0                29.6                         7.96
# 1465                  613.0                30.1                         8.15
# 1466                 4352.0                31.7                    8.17/8.17
# 1467                   85.0                29.9                         8.09
# 1470                  238.0                30.1                    8.14/8.15
# 1615                   85.0                27.2                         8.12
# 1618                  250.0                27.5                    8.20/8.20
# 1625                 2613.0                  25                  RE-sampling
# 1882                  120.0                28.4                         8.14
# 1923                   86.0                28.3                    8.24/8.24
# 2002                   74.0                27.9                         8.08
# 2075                   86.0                29.7                          8.1
# 2114                   84.0                29.1                         8.27
#
#      Observations
# 44            NaN
# 46            NaN
# 85            NaN
# 96            NaN
# 132           NaN
# 137           NaN
# 138           NaN
# 139           NaN
# 140           NaN
# 141           NaN
# 143           NaN
# 177           NaN
# 182           NaN
# 208           NaN
# 227           NaN
# 230           NaN
# 232           NaN
# 269           NaN
# 270           NaN
# 271           NaN
# 276           NaN
# 285           NaN
# 286           NaN
# 290           NaN
# 291           NaN
# 292           NaN
# 293           NaN
# 348           NaN
# 397           NaN
# 418           NaN
# ...           ...
# 1124          NaN
# 1155          NaN
# 1232          NaN
# 1240          NaN
# 1269          NaN
# 1279          NaN
# 1312          NaN
# 1320          NaN
# 1343          NaN
# 1344          NaN
# 1390          NaN
# 1399   Preliminar
# 1421   Preliminar
# 1458   Preliminar
# 1459   Preliminar
# 1460   Preliminar
# 1461   Preliminar
# 1463   Preliminar
# 1465   Preliminar
# 1466   Preliminar
# 1467   Preliminar
# 1470   Preliminar
# 1615          NaN
# 1618          NaN
# 1625          NaN
# 1882          NaN
# 1923          NaN
# 2002          NaN
# 2075          NaN
# 2114          NaN
#
# [111 rows x 11 columns]

# %%
df= Oeste.sort_values(by='Enterococcus_colonies',ascending=False).head(15)
ax= df.plot(kind='barh', x='Beach Name', y='Enterococcus_colonies', figsize=(10,5),legend=False,rot=0,color='mediumaquamarine')
ax.set_title("Beach Water Quality in the West Side of Puerto Rico", pad=30, fontsize=24)
ax.set_xlabel('Enterococci Count (MPN/100mL)')
plt.gcf().text(0.5, 0.91, "Beaches with bacteria samples exceeding Puerto Rico's Environmental Quality Board parameters from October 2015", ha='center', fontsize=12)
plt.gca().invert_yaxis()
plt.savefig("Beach Water Quality in the West Side of Puerto Rico")
plt.show()

# %%
Oeste.groupby('Beach Name').Enterococcus_colonies.max()
# Out:
# Beach Name
# Balneario Crash Boat                               452.0
# Balneario de Añasco or Balneario Tres Hermanos    4611.0
# Balneario de Boquerón                              724.0
# Balneario de Rincón                                813.0
# Balneario de Salinas                               309.0
# Caña Gorda                                         341.0
# Pico de Piedra                                    5475.0
# Playa Buyé                                        6131.0
# Playa Cabullón                                     550.0
# Playa Moja Casabe                                 1333.0
# Playa Santa                                       1785.0
# Playa del Hilton                                   471.0
# Playa el Combate                                  4352.0
# Playita Rosada                                     168.0
# Villa Lamela                                       389.0
# Name: Enterococcus_colonies, dtype: float64

# %%
playas_sucias.groupby('Beach Name').Enterococcus_colonies.max()
# Out:
# Beach Name
# Balneario Cerro Gordo or Javier Calderón Nieves      631.0
# Balneario Crash Boat                                 452.0
# Balneario El Escambrón                               331.0
# Balneario La Monserrate                              327.0
# Balneario Manuel “Nolo” Morales or Sardinera        2105.0
# Balneario Punta Guilarte                             465.0
# Balneario Punta Salinas                              368.0
# Balneario Punta Santiago                            4884.0
# Balneario Seven Seas                                 828.0
# Balneario Sun Bay                                    109.0
# Balneario de Añasco or Balneario Tres Hermanos      4611.0
# Balneario de Boquerón                                724.0
# Balneario de Carolina                                187.0
# Balneario de Patillas                                426.0
# Balneario de Puerto Nuevo                           2282.0
# Balneario de Rincón                                  813.0
# Balneario de Salinas                                 309.0
# Caña Gorda                                           341.0
# Mar Chiquita                                        1616.0
# Muelle de Arecibo                                  24196.0
# Ocean Park                                           379.0
# Pico de Piedra                                      5475.0
# Playa Azul                                          2489.0
# Playa Buyé                                          6131.0
# Playa Cabullón                                       550.0
# Playa El Alambique                                   650.0
# Playa Guayanés                                     24196.0
# Playa Guayanés                                       109.0
# Playa Moja Casabe                                   1333.0
# Playa Santa                                         1785.0
# Playa Sixto Escobar                                 5172.0
# Playa del Hilton                                     471.0
# Playa el Combate                                    4352.0
# Playita Rosada                                       168.0
# Playita del Condado                                  293.0
# Tropical Beach                                     24196.0
# Vacía Talega                                        1333.0
# Villa Lamela                                         389.0
# Name: Enterococcus_colonies, dtype: float64

# %%
playas_sucias['Year'] = playas_sucias['Date'].dt.year
playas_sucias['Month'] = playas_sucias['Date'].dt.month

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
prefinal= playas_sucias.pivot_table(index="Month",columns="Year",values="Enterococcus_colonies", aggfunc="mean").fillna(0)
plt.figure(figsize=(5, 8))
cmaps = 'viridis'
#gradient = np.linspace(0, 1, 256)
#gradient = np.vstack((gradient, gradient))
sns.heatmap(prefinal, annot=None, cmap=cmaps)
plt.savefig('Beach Water Quality per Month and Year')
plt.show()

# %%
final = playas_sucias.pivot_table(index="Beach Name",columns="Year",values="Enterococcus_colonies", aggfunc="mean").fillna(0)
plt.figure(figsize=(5, 8))
cmaps = 'viridis'
#gradient = np.linspace(0, 1, 256)
#gradient = np.vstack((gradient, gradient))
sns.heatmap(final, annot=None, cmap=cmaps)
plt.savefig('Beach Water Quality per Beach and Year')
plt.show()

# %%
df=pd.read_csv('Most visited beaches')
df
# Out:
#                          Beach        Town
# 0            Playa del Condado    San Juan
# 1        Balneario de Carolina   Carolina
# 2                     Boquerón   Cabo Rojo
# 3                         Buyé   Cabo Rojo
# 4                 El Escambrón    San Juan
# 5                        Jobos    Isabela
# 6         Balneario Seven Seas     Fajardo
# 7                     Flamenco     Culebra
# 8      Balneario La Monserrate   Luquillo
# 9                   Ocean Park    San Juan
# 10                  Isla Verde    Carolina
# 11  Playa Sucia or La Playuela   Cabo Rojo
# 12                     Piñones       Loíza
# 13                     Combate   Cabo Rojo
# 14                  Crash Boat   Aguadilla

# %%
playas_sucias['Beach Name'].value_counts()
# Out:
# Tropical Beach                                     59
# Playa Guayanés                                     40
# Muelle de Arecibo                                  35
# Balneario Manuel “Nolo” Morales or Sardinera       19
# Balneario de Patillas                              19
# Balneario Punta Santiago                           17
# Playa Moja Casabe                                  16
# Balneario de Añasco or Balneario Tres Hermanos     15
# Balneario de Puerto Nuevo                          15
# Balneario Punta Guilarte                           15
# Vacía Talega                                       12
# Balneario Cerro Gordo or Javier Calderón Nieves    11
# Balneario de Rincón                                11
# Balneario Seven Seas                               10
# Playa Buyé                                         10
# Balneario Punta Salinas                            10
# Pico de Piedra                                     10
# Balneario Crash Boat                                8
# Playa Santa                                         7
# Balneario de Salinas                                7
# Playa Sixto Escobar                                 7
# Villa Lamela                                        7
# Playa el Combate                                    6
# Playa El Alambique                                  5
# Playa Cabullón                                      5
# Caña Gorda                                          5
# Ocean Park                                          4
# Balneario de Boquerón                               4
# Mar Chiquita                                        3
# Balneario El Escambrón                              3
# Playa del Hilton                                    3
# Playita del Condado                                 3
# Balneario La Monserrate                             3
# Balneario Sun Bay                                   2
# Playa Azul                                          2
# Playita Rosada                                      2
# Balneario de Carolina                               2
# Playa Guayanés                                      1
# Name: Beach Name, dtype: int64

# %%
#Mergin two different data frames to seethe conditions of the most visited beaches
most_visited= playas_sucias[playas_sucias['Beach Name'].isin(['Playita del Condado','Balneario de Carolina',
                                                              'Balneario de Boquerón','Playa Buyé','Balneario El Escambrón',
                                                              'Balneario Seven Seas',
                                                              ,'Balneario La Monserrate',
                                                              'Ocean Park',
                                                              'Playa el Combate','Balneario Crash Boat'])] 
most_visited
# Out:
#            Date Beach ID               Beach Name   Latitude  Longitude  \
# 64   2015-10-20    RW-26      Playita del Condado  18.461131 -66.082408
# 170  2015-12-15    RW-27               Ocean Park  18.453011 -66.048881
# 232  2016-02-08    RW-16     Balneario Crash Boat  18.457667 -67.163778
# 237  2016-02-09    RW-26      Playita del Condado  18.461131 -66.082408
# 238  2016-02-09    RW-27               Ocean Park  18.453011 -66.048881
# 251  2016-02-09     RW-2     Balneario Seven Seas  18.369267 -65.636072
# 291  2016-03-07    RW-13    Balneario de Boquerón  18.019442 -67.172244
# 293  2016-03-07   RW-12B         Playa el Combate  17.974794 -67.212906
# 305  2016-03-08   RW-20A   Balneario El Escambrón  18.467236 -66.089958
# 317  2016-03-08     RW-2     Balneario Seven Seas  18.369267 -65.636072
# 377  2016-05-02     RW-2     Balneario Seven Seas  18.369267 -65.636072
# 379  2016-05-02    RW-1A  Balneario La Monserrate  18.385592 -65.729472
# 412  2016-06-07     RW-2     Balneario Seven Seas  18.369267 -65.636072
# 426  2016-06-20    RW-16     Balneario Crash Boat  18.457667 -67.163778
# 582  2016-10-03    RW-13    Balneario de Boquerón  18.019442 -67.172244
# 609  2016-11-21   RW-21C    Balneario de Carolina  18.445989 -66.003572
# 616  2016-11-21     RW-2     Balneario Seven Seas  18.369267 -65.636072
# 651  2016-11-29    RW-1A  Balneario La Monserrate  18.385592 -65.729472
# 698  2016-12-13     RW-2     Balneario Seven Seas  18.369267 -65.636072
# 704  2016-12-19     RW-2     Balneario Seven Seas  18.369267 -65.636072
# 759  2017-01-10   RW-20A   Balneario El Escambrón  18.467236 -66.089958
# 762  2017-01-10    RW-27               Ocean Park  18.453011 -66.048881
# 764  2017-01-10   RW-21C    Balneario de Carolina  18.445989 -66.003572
# 771  2017-01-10     RW-2     Balneario Seven Seas  18.369267 -65.636072
# 895  2017-02-21   RW-12B         Playa el Combate  17.974794 -67.212906
# 937  2017-03-07    RW-27               Ocean Park  18.453011 -66.048881
# 956  2017-03-06    RW-13    Balneario de Boquerón  18.019442 -67.172244
# 958  2017-03-06   RW-12B         Playa el Combate  17.974794 -67.212906
# 962  2017-03-06    RW-16     Balneario Crash Boat  18.457667 -67.163778
# 1101 2017-04-18    RW-1A  Balneario La Monserrate  18.385592 -65.729472
# 1232 2017-05-30    RW-16     Balneario Crash Boat  18.457667 -67.163778
# 1240 2017-06-05    RW-16     Balneario Crash Boat  18.457667 -67.163778
# 1390 2017-07-24    RW-16     Balneario Crash Boat  18.457667 -67.163778
# 1410 2017-08-15   RW-20A   Balneario El Escambrón  18.467236 -66.089958
# 1466 2017-08-28   RW-12B         Playa el Combate  17.974794 -67.212906
# 1470 2017-08-28    RW-16     Balneario Crash Boat  18.457667 -67.163778
# 1489 2017-11-27     RW-2     Balneario Seven Seas  18.369267 -65.636072
# 1618 2018-01-08    RW-16     Balneario Crash Boat  18.457667 -67.163778
# 1709 2018-02-20    RW-26      Playita del Condado  18.461131 -66.082408
# 1882 2018-04-30    RW-13    Balneario de Boquerón  18.019442 -67.172244
# 1923 2018-05-14   RW-12B         Playa el Combate  17.974794 -67.212906
# 1988 2018-06-12     RW-2     Balneario Seven Seas  18.369267 -65.636072
# 2114 2018-07-30   RW-12B         Playa el Combate  17.974794 -67.212906
#
#                    Sampling Route Sampling Type  Enterococcus_colonies  \
# 64        Route 1: Dorado - Loíza       Routine                  293.0
# 170       Route 1: Dorado - Loíza       Routine                  327.0
# 232   Route 5: Añasco - Aguadilla       Routine                  146.0
# 237       Route 1: Dorado - Loíza       Routine                  185.0
# 238       Route 1: Dorado - Loíza       Routine                  355.0
# 251    Route 2: Arroyo - Luquillo       Routine                   97.0
# 291            Route 4: Cabo Rojo       Routine                  122.0
# 293            Route 4: Cabo Rojo       Routine                  331.0
# 305       Route 1: Dorado - Loíza       Routine                  216.0
# 317    Route 2: Arroyo - Luquillo       Routine                  122.0
# 377    Route 2: Arroyo - Luquillo   RE-sampling                  110.0
# 379    Route 2: Arroyo - Luquillo   RE-sampling                  145.0
# 412    Route 2: Arroyo - Luquillo       Routine                  488.0
# 426   Route 5: Añasco - Aguadilla       Routine                  452.0
# 582            Route 4: Cabo Rojo       Routine                  301.0
# 609       Route 1: Dorado - Loíza   RE-sampling                  187.0
# 616    Route 2: Arroyo - Luquillo   RE-sampling                  754.0
# 651    Route 2: Arroyo - Luquillo       Routine                  102.0
# 698    Route 2: Arroyo - Luquillo       Routine                   86.0
# 704    Route 2: Arroyo - Luquillo   RE-sampling                   84.0
# 759       Route 1: Dorado - Loíza       Routine                  331.0
# 762       Route 1: Dorado - Loíza       Routine                  379.0
# 764       Route 1: Dorado - Loíza       Routine                  148.0
# 771    Route 2: Arroyo - Luquillo       Routine                  238.0
# 895            Route 4: Cabo Rojo       Routine                   75.0
# 937       Route 1: Dorado - Loíza       Routine                  309.0
# 956            Route 4: Cabo Rojo       Routine                  724.0
# 958            Route 4: Cabo Rojo       Routine                   85.0
# 962   Route 5: Añasco - Aguadilla       Routine                   97.0
# 1101   Route 2: Arroyo - Luquillo       Routine                  327.0
# 1232  Route 5: Añasco - Aguadilla       Routine                  218.0
# 1240  Route 5: Añasco - Aguadilla   RE-sampling                  169.0
# 1390  Route 5: Añasco - Aguadilla       Routine                  231.0
# 1410      Route 1: Dorado - Loíza       Routine                   75.0
# 1466           Route 4: Cabo Rojo       Routine                 4352.0
# 1470  Route 5: Añasco - Aguadilla       Routine                  238.0
# 1489   Route 2: Arroyo - Luquillo       Routine                   98.0
# 1618  Route 5: Añasco - Aguadilla       Routine                  250.0
# 1709      Route 1: Dorado - Loíza       Routine                   86.0
# 1882           Route 4: Cabo Rojo       Routine                  120.0
# 1923           Route 4: Cabo Rojo       Routine                   86.0
# 1988   Route 2: Arroyo - Luquillo       Routine                  828.0
# 2114           Route 4: Cabo Rojo       Routine                   84.0
#
#      Temperature\r\n(°C)                          pH   \
# 64                 30.50                         8.16
# 170                27.20                         8.07
# 232                27.30                    7.98/7.98
# 237                27.10                    8.06/8.08
# 238                26.80                         8.09
# 251                26.80                         7.92
# 291                27.20                         8.04
# 293                27.20                    8.06/8.06
# 305                26.10                         8.32
# 317                25.40                         8.06
# 377                26.50  Bacteriological Re-sampling
# 379                26.50  Bacteriological Re-sampling
# 412                30.00                         8.08
# 426                26.90                    8.01/8.02
# 582                29.20                         8.13
# 609                27.80  Bacteriological Re-sampling
# 616                29.00  Bacteriological Re-sampling
# 651                28.10                         8.03
# 698                25.60                         8.11
# 704                26.50  Bacteriological Re-sampling
# 759                25.20                         8.15
# 762                25.20                         8.12
# 764                25.80                         8.18
# 771                26.50                         8.02
# 895                26.00                    8.18/8.16
# 937                24.70                         8.04
# 956                26.50                         8.04
# 958                25.90                    8.19/8.20
# 962                25.00                    8.03/8.03
# 1101                26.6                         8.05
# 1232                29.1                    8.14/8.15
# 1240                28.3  Bacteriological Re-sampling
# 1390                30.1                         8.05
# 1410                28.9                         8.15
# 1466                31.7                    8.17/8.17
# 1470                30.1                    8.14/8.15
# 1489                28.5                         8.11
# 1618                27.5                    8.20/8.20
# 1709                25.3                         8.22
# 1882                28.4                         8.14
# 1923                28.3                    8.24/8.24
# 1988                28.7                         8.16
# 2114                29.1                         8.27
#
#                                            Observations  Year  Month
# 64                                                  NaN  2015     10
# 170                                                 NaN  2015     12
# 232                                                 NaN  2016      2
# 237                                                 NaN  2016      2
# 238                                                 NaN  2016      2
# 251                                                 NaN  2016      2
# 291                                                 NaN  2016      3
# 293                                                 NaN  2016      3
# 305                                                 NaN  2016      3
# 317                                                 NaN  2016      3
# 377                                                 NaN  2016      5
# 379                                                 NaN  2016      5
# 412                                                 NaN  2016      6
# 426                                                 NaN  2016      6
# 582                                                 NaN  2016     10
# 609                                                 NaN  2016     11
# 616                                                 NaN  2016     11
# 651                                                 NaN  2016     11
# 698                                                 NaN  2016     12
# 704                                                 NaN  2016     12
# 759                                                 NaN  2017      1
# 762                                                 NaN  2017      1
# 764                                                 NaN  2017      1
# 771                                                 NaN  2017      1
# 895                                                 NaN  2017      2
# 937                                                 NaN  2017      3
# 956   Proyecto Bandera Azul                         ...  2017      3
# 958                                                 NaN  2017      3
# 962                                                 NaN  2017      3
# 1101                                                NaN  2017      4
# 1232                                                NaN  2017      5
# 1240                                                NaN  2017      6
# 1390                                                NaN  2017      7
# 1410                                         Preliminar  2017      8
# 1466                                         Preliminar  2017      8
# 1470                                         Preliminar  2017      8
# 1489                                                NaN  2017     11
# 1618                                                NaN  2018      1
# 1709                                                NaN  2018      2
# 1882                                                NaN  2018      4
# 1923                                                NaN  2018      5
# 1988                                                NaN  2018      6
# 2114                                                NaN  2018      7

# %%
df2 = most_visited.pivot_table(index="Beach Name",columns="Year",values="Enterococcus_colonies", aggfunc="mean").fillna(0)
plt.figure(figsize=(5, 8))
cmaps = 'viridis'
#gradient = np.linspace(0, 1, 256)
#gradient = np.vstack((gradient, gradient))
sns.heatmap(df2, annot=None, cmap=cmaps)
plt.savefig('Dirty most visited beaches per year')
plt.show()

# %%
df2 = most_visited.pivot_table(index="Month",columns="Year",values="Enterococcus_colonies", aggfunc="mean").fillna(0)
plt.figure(figsize=(5, 8))
cmaps = 'viridis'
#gradient = np.linspace(0, 1, 256)
#gradient = np.vstack((gradient, gradient))
sns.heatmap(df2, annot=None, cmap=cmaps)
plt.savefig('Dirty most visited beaches per year and month')
plt.show()
