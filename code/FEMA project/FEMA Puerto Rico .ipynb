# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import requests
from bs4 import BeautifulSoup
import re
from cycler import cycler

# %%
#FEMA web Disaster Declarations
df=pd.read_csv('FemaWebDisasterDeclarations.csv')
df
# Out:
#       disasterNumber           declarationDate  \
# 0               3397  2018-02-11T00:00:00.000Z
# 1               3390  2017-09-18T00:00:00.000Z
# 2               4352  2017-12-20T00:00:00.000Z
# 3               3388  2017-09-08T00:00:00.000Z
# 4               3395  2017-10-08T00:00:00.000Z
# 5               3392  2017-10-06T00:00:00.000Z
# 6               4332  2017-08-25T00:00:00.000Z
# 7               4348  2017-11-14T00:00:00.000Z
# 8               3384  2017-09-05T00:00:00.000Z
# 9               4327  2017-08-05T00:00:00.000Z
# 10              4302  2017-02-14T00:00:00.000Z
# 11              4342  2017-10-07T00:00:00.000Z
# 12              4328  2017-08-08T00:00:00.000Z
# 13              4303  2017-02-17T00:00:00.000Z
# 14              4341  2017-09-27T00:00:00.000Z
# 15              4307  2017-03-27T00:00:00.000Z
# 16              4344  2017-10-10T00:00:00.000Z
# 17              4334  2017-08-27T00:00:00.000Z
# 18              4308  2017-04-01T00:00:00.000Z
# ...

# %%
df[df['disasterName']=='HURRICANE MARIA']
# Out:
#     disasterNumber           declarationDate     disasterName  \
# 1             3390  2017-09-18T00:00:00.000Z  HURRICANE MARIA
# 34            3391  2017-09-18T00:00:00.000Z  HURRICANE MARIA
# 51            4339  2017-09-20T00:00:00.000Z  HURRICANE MARIA
# 68            4340  2017-09-20T00:00:00.000Z  HURRICANE MARIA
#
#            incidentBeginDate           incidentEndDate declarationType  \
# 1   2017-09-16T00:00:00.000Z  2017-09-22T00:00:00.000Z       Emergency
# 34  2017-09-17T00:00:00.000Z  2017-11-15T00:00:00.000Z       Emergency
# 51  2017-09-17T00:00:00.000Z  2017-11-15T00:00:00.000Z  Major Disaster
# 68  2017-09-16T00:00:00.000Z  2017-09-22T00:00:00.000Z  Major Disaster
#
#    stateCode                       stateName incidentType  \
# 1         VI  Virgin Islands of the U.S.        Hurricane
# 34        PR  Puerto Rico                       Hurricane
# 51        PR  Puerto Rico                       Hurricane
# 68        VI  Virgin Islands of the U.S.        Hurricane
#
# ...
